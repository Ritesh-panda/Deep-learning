# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh-panda/Deep-learning/blob/main/CNN_image_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from cv2 import resize
import random
from skimage import exposure,transform
from skimage.util import random_noise

# %%
img=mpimg.imread("/content/download1.jpg")

# %%
plt.imshow(img)

# %%
#rescaling
img_rescale=resize(img,(10000,10000))
plt.imshow(img_rescale)

# %%
#rescaling
img_rescale=resize(img,(40,40))
plt.imshow(img_rescale)
